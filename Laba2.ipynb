# %% [markdown]
# <a href="https://colab.research.google.com/github/snickers24/Stone-iceland/blob/main/Laba2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Лабораторная работа №2 вариант 7

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import numpy as np

# Загрузка данных из файла
data = pd.read_csv('Current.csv')

# Взятие первых 1280 значений
current = data[:1280]

# Подсчет среднего значения силы тока
mean_current = current.mean()
I=mean_current
# Вычисление мощности и построение графика
power = current**2 * 10
plt.plot(power)
plt.title('График начений мощности')
plt.xlabel('Сила тока')
plt.ylabel('Мощность')
# Отображение графика
plt.show()
Pow=I**2*10
mpg = power.mean()
mpf = np.square(mean_current) * 10
print(Pow)
mpg
I
# Out:
# 2200    331922.851562
# dtype: float64
# 2200   -182.1875
# dtype: float64
